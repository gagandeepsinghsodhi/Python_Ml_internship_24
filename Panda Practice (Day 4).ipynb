# %%
import numpy as np
import pandas as pd

# %%
disc = {
    "Name": ["Ram", "Shayam", "Sameer", "Kajal", "Irfan", "Rohit"],
    "Roll no" : [1,2,3,4,5,6],
    "Grades": ["A", "B", "C", "C", "B", "A"],
    "Email" : ["abc@gmail.com", 
               "def@gmail.com", 
               "ghi@gmail.com",
               "jkl@gmail.com", 
               "mno@gmail.com",
               "pqr@gmail.com",]
}
disc
# Out:
# {'Name': ['Ram', 'Shayam', 'Sameer', 'Kajal', 'Irfan', 'Rohit'],
#  'Roll no': [1, 2, 3, 4, 5, 6],
#  'Grades': ['A', 'B', 'C', 'C', 'B', 'A'],
#  'Email': ['abc@gmail.com',
#   'def@gmail.com',
#   'ghi@gmail.com',
#   'jkl@gmail.com',
#   'mno@gmail.com',
#   'pqr@gmail.com']}

# %%
df = pd.DataFrame(disc)
df
# Out:
#      Name  Roll no Grades          Email
# 0     Ram        1      A  abc@gmail.com
# 1  Shayam        2      B  def@gmail.com
# 2  Sameer        3      C  ghi@gmail.com
# 3   Kajal        4      C  jkl@gmail.com
# 4   Irfan        5      B  mno@gmail.com
# 5   Rohit        6      A  pqr@gmail.com

# %%
# Top 5  Entities  of the table
df.head()
# Out:
#      Name  Roll no Grades          Email
# 0     Ram        1      A  abc@gmail.com
# 1  Shayam        2      B  def@gmail.com
# 2  Sameer        3      C  ghi@gmail.com
# 3   Kajal        4      C  jkl@gmail.com
# 4   Irfan        5      B  mno@gmail.com

# %%
# last 5 entites of the table
df.tail()
# Out:
#      Name  Roll no Grades          Email
# 1  Shayam        2      B  def@gmail.com
# 2  Sameer        3      C  ghi@gmail.com
# 3   Kajal        4      C  jkl@gmail.com
# 4   Irfan        5      B  mno@gmail.com
# 5   Rohit        6      A  pqr@gmail.com

# %%
df.tail(2)
# Out:
#     Name  Roll no Grades          Email
# 4  Irfan        5      B  mno@gmail.com
# 5  Rohit        6      A  pqr@gmail.com

# %%
df.describe()
# Out:
#         Roll no
# count  6.000000
# mean   3.500000
# std    1.870829
# min    1.000000
# 25%    2.250000
# 50%    3.500000
# 75%    4.750000
# max    6.000000

# %%
cus= pd.read_csv("Customer Table.csv")
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
type(cus)
# Out:
# pandas.core.frame.DataFrame

# %%
type(cus["CustomerID"])
# Out:
# pandas.core.series.Series

# %%
cus.index
# Out:
# RangeIndex(start=0, stop=91, step=1)

# %%
cus.columns # from columns we get all the headers from the tabole
# Out:
# Index(['CustomerID', 'Company Name', 'Costumer Name', 'City', 'PostalCode',
#        'Country'],
#       dtype='object')

# %%
cus.to_numpy()# making 2D array
# Out:
# array([[1, 'Alfreds Futterkiste', 'Maria Anders', 'Berlin', 12209,
#         'Germany'],
#        [2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo',
#         'Mexico D.F.', 5021, 'Mexico'],
#        [3, 'Antonio Moreno Taqueria', 'Antonio Moreno', 'Mexico D.F.',
#         5023, 'Mexico'],
#        [4, 'Around the Horn', 'Thomas Hardy', 'London', 34626, 'UK'],
#        [5, 'Berglunds snabbkp', 'Christina Berglund', 'Lulea', 95822,
#         'Sweden'],
#        [6, 'Blauer See Delikatessen', 'Hanna Moos', 'Mannheim', 68306,
#         'Germany'],
#        [7, 'Blondel pere et fils', 'Frederique Citeaux', 'Strasbourg',
#         67000, 'France'],
#        [8, 'BOlido Comidas preparadas', 'Martin Sommer', 'Madrid', 28023,
#         'Spain'],
#        [9, 'Bon app', 'Laurence Lebihans', 'Marseille', 13008, 'France'],
#        [10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'Tsawassen',
#         254685, 'Canada'],
# ...

# %%
cus.T
# Out:
#                                 0                                   1   \
# CustomerID                       1                                   2
# Company Name   Alfreds Futterkiste  Ana Trujillo Emparedados y helados
# Costumer Name         Maria Anders                        Ana Trujillo
# City                        Berlin                         Mexico D.F.
# PostalCode                   12209                                5021
# Country                    Germany                              Mexico
#
#                                     2                3                   4   \
# CustomerID                           3                4                   5
# Company Name   Antonio Moreno Taqueria  Around the Horn   Berglunds snabbkp
# Costumer Name           Antonio Moreno     Thomas Hardy  Christina Berglund
# City                       Mexico D.F.           London               Lulea
# PostalCode                        5023            34626               95822
# ...

# %%
cus.drop(3, axis = 0)
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
cus.loc[(48,78),("Company Name", "Costumer Name")]
# Out:
#                     Company Name     Costumer Name
# 48  Magazzini Alimentari Riuniti  Giovanni Rovelli
# 78            Toms Spezialitaten     Karin Josephs

# %%
cus.loc[tuple((np.arange(6,8))),("Company Name", "Costumer Name")]
# Out:
#                 Company Name       Costumer Name
# 6       Blondel pere et fils  Frederique Citeaux
# 7  BOlido Comidas preparadas       Martin Sommer

# %%
cus.loc[np.arange(48,78),:]
# Out:
#     CustomerID                  Company Name        Costumer Name  \
# 48          49  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49          50                  Maison Dewey      Catherine Dewey
# 50          51                Mere Paillarde       Jean Fresniere
# 51          52        Morgenstern Gesundkost      Alexander Feuer
# 52          53                   North/South       Simon Crowther
# 53          54        Oceano Atlantico Ltda.       Yvonne Moncada
# 54          55        Old World Delicatessen        Rene Phillips
# 55          56            Ottilies Kaseladen  Henriette Pfalzheim
# 56          57             Paris specialites       Marie Bertrand
# 57          58     Pericles Comidas clasicas  Guillermo Fernandez
# 58          59              Piccolo und mehr          Georg Pipps
# 59          60       Princesa Isabel Vinhoss     Isabel de Castro
# 60          61                   Que Delicia     Bernardo Batista
# ...

# %%
cus.loc[:, "Company Name"]
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
np.array(cus.loc[:, "Company Name"])
# Out:
# array(['Alfreds Futterkiste', 'Ana Trujillo Emparedados y helados',
#        'Antonio Moreno Taqueria', 'Around the Horn', 'Berglunds snabbkp',
#        'Blauer See Delikatessen', 'Blondel pere et fils',
#        'BOlido Comidas preparadas', 'Bon app', 'Bottom-Dollar Marketse',
#        'Bs Beverages', 'Cactus Comidas para llevar',
#        'Centro comercial Moctezuma', 'Chop-suey Chinese',
#        'Comercio Mineiro', 'Consolidated Holdings',
#        'Drachenblut Delikatessend', 'Du monde entier',
#        'Eastern Connection', 'Ernst Handel', 'Familia Arquibaldo',
#        'FISSA Fabrica Inter. Salchichas S.A.', 'Folies gourmandes',
#        'Folk och fa HB', 'Frankenversand', 'France restauration',
#        'Franchi S.p.A.', 'Furia Bacalhau e Frutos do Mar',
#        'Galeria del gastrOnomo', 'Godos Cocina Tipica',
#        'Gourmet Lanchonetes', 'Great Lakes Food Market',
#        'GROSELLA-Restaurante', 'Hanari Carnes', 'HILARION-Abastos',
# ...

# %%
cn = cus.loc[:, "Company Name"]
cn
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
company_data = {
    1: {"Company Name": "Tech Innovators", "Employee Name": "John Smith", "Position": "Software Engineer"},
    2: {"Company Name": "Creative Solutions", "Employee Name": "Jane Doe", "Position": "Graphic Designer"},
    3: {"Company Name": "HealthFirst", "Employee Name": "Emily Davis", "Position": "Nurse"},
    4: {"Company Name": "Green Energy", "Employee Name": "Michael Brown", "Position": "Project Manager"},
    5: {"Company Name": "Global Finance", "Employee Name": "Laura Wilson", "Position": "Financial Analyst"},
    6: {"Company Name": "EduTech", "Employee Name": "Chris Johnson", "Position": "Data Scientist"},
    7: {"Company Name": "Urban Builders", "Employee Name": "Amanda Taylor", "Position": "Architect"},
    8: {"Company Name": "Cyber Secure", "Employee Name": "David Lee", "Position": "Cybersecurity Specialist"},
    9: {"Company Name": "Aero Dynamics", "Employee Name": "Sarah Moore", "Position": "Aerospace Engineer"},
    10: {"Company Name": "WellCare", "Employee Name": "Daniel Martin", "Position": "Pharmacist"},
    11: {"Company Name": "Tech Innovators", "Employee Name": "James Anderson", "Position": "DevOps Engineer"},
    12: {"Company Name": "Creative Solutions", "Employee Name": "Olivia Thomas", "Position": "Content Writer"},
    13: {"Company Name": "HealthFirst", "Employee Name": "Megan Harris", "Position": "Physical Therapist"},
    14: {"Company Name": "Green Energy", "Employee Name": "Andrew Lewis", "Position": "Environmental Consultant"},
    15: {"Company Name": "Global Finance", "Employee Name": "Sophia Walker", "Position": "Accountant"},
    16: {"Company Name": "EduTech", "Employee Name": "Ryan Hall", "Position": "Machine Learning Engineer"},
    17: {"Company Name": "Urban Builders", "Employee Name": "Jessica Allen", "Position": "Interior Designer"},
    18: {"Company Name": "Cyber Secure", "Employee Name": "Ethan Young", "Position": "Network Administrator"},
    19: {"Company Name": "Aero Dynamics", "Employee Name": "Madison King", "Position": "Mechanical Engineer"},
    20: {"Company Name": "WellCare", "Employee Name": "Joshua Wright", "Position": "Radiologist"},
    21: {"Company Name": "Tech Innovators", "Employee Name": "Matthew Scott", "Position": "Product Manager"},
    22: {"Company Name": "Creative Solutions", "Employee Name": "Ava Green", "Position": "Marketing Specialist"},
    23: {"Company Name": "HealthFirst", "Employee Name": "Chloe Baker", "Position": "Dietitian"},
    24: {"Company Name": "Green Energy", "Employee Name": "Benjamin Adams", "Position": "Sustainability Officer"},
    25: {"Company Name": "Global Finance", "Employee Name": "Zoe Nelson", "Position": "Risk Analyst"},
    26: {"Company Name": "EduTech", "Employee Name": "Liam Carter", "Position": "Education Consultant"},
    27: {"Company Name": "Urban Builders", "Employee Name": "Isabella Perez", "Position": "Construction Manager"},
    28: {"Company Name": "Cyber Secure", "Employee Name": "Mason Roberts", "Position": "IT Support Specialist"},
    29: {"Company Name": "Aero Dynamics", "Employee Name": "Ella Reed", "Position": "Aviation Engineer"},
    30: {"Company Name": "WellCare", "Employee Name": "Samuel Turner", "Position": "Physical Therapist"},
    31: {"Company Name": "Tech Innovators", "Employee Name": "Grace Lewis", "Position": "Data Analyst"},
    32: {"Company Name": "Creative Solutions", "Employee Name": "Jackson Torres", "Position": "SEO Specialist"},
    33: {"Company Name": "HealthFirst", "Employee Name": "Hannah Stewart", "Position": "Medical Lab Technician"},
    34: {"Company Name": "Green Energy", "Employee Name": "Lucas Murphy", "Position": "Energy Consultant"},
    35: {"Company Name": "Global Finance", "Employee Name": "Lily Collins", "Position": "Investment Analyst"},
    36: {"Company Name": "EduTech", "Employee Name": "Aiden Ramirez", "Position": "Curriculum Developer"},
    37: {"Company Name": "Urban Builders", "Employee Name": "Mia Cox", "Position": "Surveyor"},
    38: {"Company Name": "Cyber Secure", "Employee Name": "Harper Howard", "Position": "Security Analyst"},
    39: {"Company Name": "Aero Dynamics", "Employee Name": "Jayden Price", "Position": "Flight Engineer"},
    40: {"Company Name": "WellCare", "Employee Name": "Sophie Hughes", "Position": "Registered Nurse"},
    41: {"Company Name": "Tech Innovators", "Employee Name": "Alexander Barnes", "Position": "UX Designer"},
    42: {"Company Name": "Creative Solutions", "Employee Name": "Aria Bell", "Position": "Copywriter"},
    43: {"Company Name": "HealthFirst", "Employee Name": "Gabriel Ramirez", "Position": "Respiratory Therapist"},
    44: {"Company Name": "Green Energy", "Employee Name": "Natalie Rivera", "Position": "Environmental Scientist"},
    45: {"Company Name": "Global Finance", "Employee Name": "David Hughes", "Position": "Credit Analyst"},
    46: {"Company Name": "EduTech", "Employee Name": "Ella Jenkins", "Position": "Learning Specialist"},
    47: {"Company Name": "Urban Builders", "Employee Name": "Victoria Perry", "Position": "Urban Planner"},
    48: {"Company Name": "Cyber Secure", "Employee Name": "Henry Cooper", "Position": "Penetration Tester"},
    49: {"Company Name": "Aero Dynamics", "Employee Name": "Charlotte Brooks", "Position": "Systems Engineer"},
    50: {"Company Name": "WellCare", "Employee Name": "Scarlett Morris", "Position": "Occupational Therapist"},
}
company_data
# Out:
# {1: {'Company Name': 'Tech Innovators',
#   'Employee Name': 'John Smith',
#   'Position': 'Software Engineer'},
#  2: {'Company Name': 'Creative Solutions',
#   'Employee Name': 'Jane Doe',
#   'Position': 'Graphic Designer'},
#  3: {'Company Name': 'HealthFirst',
#   'Employee Name': 'Emily Davis',
#   'Position': 'Nurse'},
#  4: {'Company Name': 'Green Energy',
#   'Employee Name': 'Michael Brown',
#   'Position': 'Project Manager'},
#  5: {'Company Name': 'Global Finance',
#   'Employee Name': 'Laura Wilson',
#   'Position': 'Financial Analyst'},
#  6: {'Company Name': 'EduTech',
#   'Employee Name': 'Chris Johnson',
#   'Position': 'Data Scientist'},
#  7: {'Company Name': 'Urban Builders',
#   'Employee Name': 'Amanda Taylor',
#   'Position': 'Architect'},
#  8: {'Company Name': 'Cyber Secure',
#   'Employee Name': 'David Lee',
#   'Position': 'Cybersecurity Specialist'},
#  9: {'Company Name': 'Aero Dynamics',
#   'Employee Name': 'Sarah Moore',
# ...

# %%
cd=pd.DataFrame(company_data)
cd
# Out:
#                               1                   2            3   \
# Company Name     Tech Innovators  Creative Solutions  HealthFirst
# Employee Name         John Smith            Jane Doe  Emily Davis
# Position       Software Engineer    Graphic Designer        Nurse
#
#                             4                  5               6   \
# Company Name      Green Energy     Global Finance         EduTech
# Employee Name    Michael Brown       Laura Wilson   Chris Johnson
# Position       Project Manager  Financial Analyst  Data Scientist
#
#                            7                         8                   9   \
# Company Name   Urban Builders              Cyber Secure       Aero Dynamics
# Employee Name   Amanda Taylor                 David Lee         Sarah Moore
# Position            Architect  Cybersecurity Specialist  Aerospace Engineer
#
#                           10  ...                41                  42  \
# ...

# %%
cd.T
# Out:
#           Company Name     Employee Name                   Position
# 1      Tech Innovators        John Smith          Software Engineer
# 2   Creative Solutions          Jane Doe           Graphic Designer
# 3          HealthFirst       Emily Davis                      Nurse
# 4         Green Energy     Michael Brown            Project Manager
# 5       Global Finance      Laura Wilson          Financial Analyst
# 6              EduTech     Chris Johnson             Data Scientist
# 7       Urban Builders     Amanda Taylor                  Architect
# 8         Cyber Secure         David Lee   Cybersecurity Specialist
# 9        Aero Dynamics       Sarah Moore         Aerospace Engineer
# 10            WellCare     Daniel Martin                 Pharmacist
# 11     Tech Innovators    James Anderson            DevOps Engineer
# 12  Creative Solutions     Olivia Thomas             Content Writer
# 13         HealthFirst      Megan Harris         Physical Therapist
# ...

# %%
cd.drop_duplicates(subset= 'Company_Name', keep = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7684\1965555080.py in ?()
# ----> 1 cd.drop_duplicates(subset= 'Company_Name', keep = False)
#
# C:\Program Files\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep, inplace, ignore_index)
#    6814
#    6815         inplace = validate_bool_kwarg(inplace, "inplace")
#    6816         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6817
# -> 6818         result = self[-self.duplicated(subset, keep=keep)]
#    6819         if ignore_index:
#    6820             result.index = default_index(len(result))
#    6821
#
# C:\Program Files\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep)
#    6946         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6947         # key that doesn't exist.
# ...

# %%
cd.drop_duplicates(subset= "Company_Name", keep= "first")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7684\3711397838.py in ?()
# ----> 1 cd.drop_duplicates(subset= "Company_Name", keep= "first")
#
# C:\Program Files\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep, inplace, ignore_index)
#    6814
#    6815         inplace = validate_bool_kwarg(inplace, "inplace")
#    6816         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6817
# -> 6818         result = self[-self.duplicated(subset, keep=keep)]
#    6819         if ignore_index:
#    6820             result.index = default_index(len(result))
#    6821
#
# C:\Program Files\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep)
#    6946         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6947         # key that doesn't exist.
# ...

# %%
company_data = {
    1: {"Company Name": "Tech Innovators", "Employee Name": "John Smith", "Position": "Software Engineer"},
    2: {"Company Name": "Creative Solutions", "Employee Name": "Jane Doe", "Position": "Graphic Designer"},
    3: {"Company Name": "HealthFirst", "Employee Name": "Emily Davis", "Position": "Nurse"},
    4: {"Company Name": "Green Energy", "Employee Name": "Michael Brown", "Position": "Project Manager"},
    5: {"Company Name": "Global Finance", "Employee Name": "Laura Wilson", "Position": "Financial Analyst"},
    6: {"Company Name": "EduTech", "Employee Name": "Chris Johnson", "Position": "Data Scientist"},
    7: {"Company Name": "Urban Builders", "Employee Name": "Amanda Taylor", "Position": "Architect"},
    8: {"Company Name": "Cyber Secure", "Employee Name": "David Lee", "Position": "Cybersecurity Specialist"},
    9: {"Company Name": "Aero Dynamics", "Employee Name": "Sarah Moore", "Position": "Aerospace Engineer"},
    10: {"Company Name": "WellCare", "Employee Name": "Daniel Martin", "Position": "Pharmacist"},
    11: {"Company Name": "Tech Innovators", "Employee Name": "James Anderson", "Position": "DevOps Engineer"},
    12: {"Company Name": "Creative Solutions", "Employee Name": "Olivia Thomas", "Position": "Content Writer"},
    13: {"Company Name": "HealthFirst", "Employee Name": "Megan Harris", "Position": "Physical Therapist"},
    14: {"Company Name": "Green Energy", "Employee Name": "Andrew Lewis", "Position": "Environmental Consultant"},
    15: {"Company Name": "Global Finance", "Employee Name": "Sophia Walker", "Position": "Accountant"},
    16: {"Company Name": "EduTech", "Employee Name": "Ryan Hall", "Position": "Machine Learning Engineer"},
    17: {"Company Name": "Urban Builders", "Employee Name": "Jessica Allen", "Position": "Interior Designer"},
    18: {"Company Name": "Cyber Secure", "Employee Name": "Ethan Young", "Position": "Network Administrator"},
    19: {"Company Name": "Aero Dynamics", "Employee Name": "Madison King", "Position": "Mechanical Engineer"},
    20: {"Company Name": "WellCare", "Employee Name": "Joshua Wright", "Position": "Radiologist"},
    21: {"Company Name": "Tech Innovators", "Employee Name": "Matthew Scott", "Position": "Product Manager"},
    22: {"Company Name": "Creative Solutions", "Employee Name": "Ava Green", "Position": "Marketing Specialist"},
    23: {"Company Name": "HealthFirst", "Employee Name": "Chloe Baker", "Position": "Dietitian"},
    24: {"Company Name": "Green Energy", "Employee Name": "Benjamin Adams", "Position": "Sustainability Officer"},
    25: {"Company Name": "Global Finance", "Employee Name": "Zoe Nelson", "Position": "Risk Analyst"},
    26: {"Company Name": "EduTech", "Employee Name": "Liam Carter", "Position": "Education Consultant"},
    27: {"Company Name": "Urban Builders", "Employee Name": "Isabella Perez", "Position": "Construction Manager"},
    28: {"Company Name": "Cyber Secure", "Employee Name": "Mason Roberts", "Position": "IT Support Specialist"},
    29: {"Company Name": "Aero Dynamics", "Employee Name": "Ella Reed", "Position": "Aviation Engineer"},
    30: {"Company Name": "WellCare", "Employee Name": "Samuel Turner", "Position": "Physical Therapist"},
    31: {"Company Name": "Tech Innovators", "Employee Name": "Grace Lewis", "Position": "Data Analyst"},
    32: {"Company Name": "Creative Solutions", "Employee Name": "Jackson Torres", "Position": "SEO Specialist"},
    33: {"Company Name": "HealthFirst", "Employee Name": "Hannah Stewart", "Position": "Medical Lab Technician"},
    34: {"Company Name": "Green Energy", "Employee Name": "Lucas Murphy", "Position": "Energy Consultant"},
    35: {"Company Name": "Global Finance", "Employee Name": "Lily Collins", "Position": "Investment Analyst"},
    36: {"Company Name": "EduTech", "Employee Name": "Aiden Ramirez", "Position": "Curriculum Developer"},
    37: {"Company Name": "Urban Builders", "Employee Name": "Mia Cox", "Position": "Surveyor"},
    38: {"Company Name": "Cyber Secure", "Employee Name": "Harper Howard", "Position": "Security Analyst"},
    39: {"Company Name": "Aero Dynamics", "Employee Name": "Jayden Price", "Position": "Flight Engineer"},
    40: {"Company Name": "WellCare", "Employee Name": "Sophie Hughes", "Position": "Registered Nurse"},
    41: {"Company Name": "Tech Innovators", "Employee Name": "Alexander Barnes", "Position": "UX Designer"},
    42: {"Company Name": "Creative Solutions", "Employee Name": "Aria Bell", "Position": "Copywriter"},
    43: {"Company Name": "HealthFirst", "Employee Name": "Gabriel Ramirez", "Position": "Respiratory Therapist"},
    44: {"Company Name": "Green Energy", "Employee Name": "Natalie Rivera", "Position": "Environmental Scientist"},
    45: {"Company Name": "Global Finance", "Employee Name": "David Hughes", "Position": "Credit Analyst"},
    46: {"Company Name": "EduTech", "Employee Name": "Ella Jenkins", "Position": "Learning Specialist"},
    47: {"Company Name": "Urban Builders", "Employee Name": "Victoria Perry", "Position": "Urban Planner"},
    48: {"Company Name": "Cyber Secure", "Employee Name": "Henry Cooper", "Position": "Penetration Tester"},
    49: {"Company Name": "Aero Dynamics", "Employee Name": "Charlotte Brooks", "Position": "Systems Engineer"},
    50: {"Company Name": "WellCare", "Employee Name": "Scarlett Morris", "Position": "Occupational Therapist"},
}
company_data
# Out:
# {1: {'Company Name': 'Tech Innovators',
#   'Employee Name': 'John Smith',
#   'Position': 'Software Engineer'},
#  2: {'Company Name': 'Creative Solutions',
#   'Employee Name': 'Jane Doe',
#   'Position': 'Graphic Designer'},
#  3: {'Company Name': 'HealthFirst',
#   'Employee Name': 'Emily Davis',
#   'Position': 'Nurse'},
#  4: {'Company Name': 'Green Energy',
#   'Employee Name': 'Michael Brown',
#   'Position': 'Project Manager'},
#  5: {'Company Name': 'Global Finance',
#   'Employee Name': 'Laura Wilson',
#   'Position': 'Financial Analyst'},
#  6: {'Company Name': 'EduTech',
#   'Employee Name': 'Chris Johnson',
#   'Position': 'Data Scientist'},
#  7: {'Company Name': 'Urban Builders',
#   'Employee Name': 'Amanda Taylor',
#   'Position': 'Architect'},
#  8: {'Company Name': 'Cyber Secure',
#   'Employee Name': 'David Lee',
#   'Position': 'Cybersecurity Specialist'},
#  9: {'Company Name': 'Aero Dynamics',
#   'Employee Name': 'Sarah Moore',
# ...

# %%
cd = pd.DataFrame(company_data)
cd
# Out:
#                               1                   2            3   \
# Company Name     Tech Innovators  Creative Solutions  HealthFirst
# Employee Name         John Smith            Jane Doe  Emily Davis
# Position       Software Engineer    Graphic Designer        Nurse
#
#                             4                  5               6   \
# Company Name      Green Energy     Global Finance         EduTech
# Employee Name    Michael Brown       Laura Wilson   Chris Johnson
# Position       Project Manager  Financial Analyst  Data Scientist
#
#                            7                         8                   9   \
# Company Name   Urban Builders              Cyber Secure       Aero Dynamics
# Employee Name   Amanda Taylor                 David Lee         Sarah Moore
# Position            Architect  Cybersecurity Specialist  Aerospace Engineer
#
#                           10  ...                41                  42  \
# ...

# %%
cd = cd.T

# %%
cd.drop_duplicates(subset = "Company Name",keep = False)
# Out:
# Empty DataFrame
# Columns: [Company Name, Employee Name, Position]
# Index: []

# %%
cd
# Out:
#           Company Name     Employee Name                   Position
# 1      Tech Innovators        John Smith          Software Engineer
# 2   Creative Solutions          Jane Doe           Graphic Designer
# 3          HealthFirst       Emily Davis                      Nurse
# 4         Green Energy     Michael Brown            Project Manager
# 5       Global Finance      Laura Wilson          Financial Analyst
# 6              EduTech     Chris Johnson             Data Scientist
# 7       Urban Builders     Amanda Taylor                  Architect
# 8         Cyber Secure         David Lee   Cybersecurity Specialist
# 9        Aero Dynamics       Sarah Moore         Aerospace Engineer
# 10            WellCare     Daniel Martin                 Pharmacist
# 11     Tech Innovators    James Anderson            DevOps Engineer
# 12  Creative Solutions     Olivia Thomas             Content Writer
# 13         HealthFirst      Megan Harris         Physical Therapist
# ...

# %%
cd.to_csv("Company data.csv")
cd
# Out:
#           Company Name     Employee Name                   Position
# 1      Tech Innovators        John Smith          Software Engineer
# 2   Creative Solutions          Jane Doe           Graphic Designer
# 3          HealthFirst       Emily Davis                      Nurse
# 4         Green Energy     Michael Brown            Project Manager
# 5       Global Finance      Laura Wilson          Financial Analyst
# 6              EduTech     Chris Johnson             Data Scientist
# 7       Urban Builders     Amanda Taylor                  Architect
# 8         Cyber Secure         David Lee   Cybersecurity Specialist
# 9        Aero Dynamics       Sarah Moore         Aerospace Engineer
# 10            WellCare     Daniel Martin                 Pharmacist
# 11     Tech Innovators    James Anderson            DevOps Engineer
# 12  Creative Solutions     Olivia Thomas             Content Writer
# 13         HealthFirst      Megan Harris         Physical Therapist
# ...

# %%
cd.to_csv("company data.csv", index = False)

# %% [markdown]
# Xlrd and Openpyxl are the libraries to handle Excel files in Pandas

# %%
com_dat = pd.read_csv("Company data.csv")
com_dat
# Out:
#     Unnamed: 0        Company Name     Employee Name  \
# 0            1     Tech Innovators        John Smith
# 1            2  Creative Solutions          Jane Doe
# 2            3         HealthFirst       Emily Davis
# 3            4        Green Energy     Michael Brown
# 4            5      Global Finance      Laura Wilson
# 5            6             EduTech     Chris Johnson
# 6            7      Urban Builders     Amanda Taylor
# 7            8        Cyber Secure         David Lee
# 8            9       Aero Dynamics       Sarah Moore
# 9           10            WellCare     Daniel Martin
# 10          11     Tech Innovators    James Anderson
# 11          12  Creative Solutions     Olivia Thomas
# 12          13         HealthFirst      Megan Harris
# 13          14        Green Energy      Andrew Lewis
# 14          15      Global Finance     Sophia Walker
# 15          16             EduTech         Ryan Hall
# 16          17      Urban Builders     Jessica Allen
# ...

# %%
com_dat.drop(2, axis=0)
# Out:
#     Unnamed: 0        Company Name     Employee Name  \
# 0            1     Tech Innovators        John Smith
# 1            2  Creative Solutions          Jane Doe
# 3            4        Green Energy     Michael Brown
# 4            5      Global Finance      Laura Wilson
# 5            6             EduTech     Chris Johnson
# 6            7      Urban Builders     Amanda Taylor
# 7            8        Cyber Secure         David Lee
# 8            9       Aero Dynamics       Sarah Moore
# 9           10            WellCare     Daniel Martin
# 10          11     Tech Innovators    James Anderson
# 11          12  Creative Solutions     Olivia Thomas
# 12          13         HealthFirst      Megan Harris
# 13          14        Green Energy      Andrew Lewis
# 14          15      Global Finance     Sophia Walker
# 15          16             EduTech         Ryan Hall
# 16          17      Urban Builders     Jessica Allen
# 17          18        Cyber Secure       Ethan Young
# ...

# %%
com_dat
# Out:
#     Unnamed: 0        Company Name     Employee Name  \
# 0            1     Tech Innovators        John Smith
# 1            2  Creative Solutions          Jane Doe
# 2            3         HealthFirst       Emily Davis
# 3            4        Green Energy     Michael Brown
# 4            5      Global Finance      Laura Wilson
# 5            6             EduTech     Chris Johnson
# 6            7      Urban Builders     Amanda Taylor
# 7            8        Cyber Secure         David Lee
# 8            9       Aero Dynamics       Sarah Moore
# 9           10            WellCare     Daniel Martin
# 10          11     Tech Innovators    James Anderson
# 11          12  Creative Solutions     Olivia Thomas
# 12          13         HealthFirst      Megan Harris
# 13          14        Green Energy      Andrew Lewis
# 14          15      Global Finance     Sophia Walker
# 15          16             EduTech         Ryan Hall
# 16          17      Urban Builders     Jessica Allen
# ...

# %%
com_dat.reset_index(drop=True,inplace=True)

# %%
com_dat
# Out:
#     Unnamed: 0        Company Name     Employee Name  \
# 0            1     Tech Innovators        John Smith
# 1            2  Creative Solutions          Jane Doe
# 2            4        Green Energy     Michael Brown
# 3            5      Global Finance      Laura Wilson
# 4            6             EduTech     Chris Johnson
# 5            7      Urban Builders     Amanda Taylor
# 6            8        Cyber Secure         David Lee
# 7            9       Aero Dynamics       Sarah Moore
# 8           10            WellCare     Daniel Martin
# 9           11     Tech Innovators    James Anderson
# 10          12  Creative Solutions     Olivia Thomas
# 11          13         HealthFirst      Megan Harris
# 12          14        Green Energy      Andrew Lewis
# 13          15      Global Finance     Sophia Walker
# 14          16             EduTech         Ryan Hall
# 15          17      Urban Builders     Jessica Allen
# 16          18        Cyber Secure       Ethan Young
# ...

# %%
com_dat.to_csv("Company data.csv",index =False)

# %%
com_dat.to_excel("Company data.xlsx")
